# %%
import pandas as pd
import os

# %%
base_dir = "/Users/anonymous_user/Downloads/experiment_results/exp2_extraction_results/llama_extractions/distilled_llama_extraction/distilled_llama_extraction/run5"
result_dfs = []
for file in os.listdir(base_dir):
    if file.endswith(".csv"):
        df = pd.read_csv(os.path.join(base_dir, file))
        result_dfs.append(df)
df_extraction = pd.concat(result_dfs, ignore_index=True)

# %%
df_extraction[df_extraction['extraction_BLEU_DS']==1].count()

# %%
290/875

# %%
5434/12864

# %%
df = pd.read_csv("/Users/anonymous_user/Downloads/work_usb/research_projects_data/memorization/outputs/7b_model/extraction_results/extraction_result_run1/repo_path_size_copies_contents_000000000002.csv")

# %%
df.head()
